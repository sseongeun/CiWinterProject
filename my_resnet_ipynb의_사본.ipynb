# %% [markdown]
# <a href="https://colab.research.google.com/github/sseongeun/CiWinterProject/blob/main/my_resnet_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

from keras.utils.np_utils import to_categorical
from keras.models import Sequential, load_model, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.datasets import cifar10



import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler

# %%
#plt.figure(figsize=(1,1))  # 너비와 높이를 모두 3인치로 설정
#plt.imshow(x_train[0],cmap='binary')
#plt.show

# %%
#resnet 모델 구현 코드
def ResnetBlock(num_filters, input_layer, strides=(1, 1)):
    shortcut = input_layer
    if strides != (1, 1) or input_layer.shape[-1] != num_filters:
        shortcut = layers.Conv2D(num_filters, (1, 1), strides=strides, padding='valid', kernel_initializer='he_normal')(input_layer)

    x = layers.Conv2D(num_filters, (3, 3), padding='same', strides=strides, kernel_initializer='he_normal')(input_layer)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    x = layers.Conv2D(num_filters, (3, 3), padding='same', kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Add()([shortcut, x])
    x = layers.Activation('relu')(x)
    
    return x

def ResNet(input_shape, num_classes=10):
    inputs = layers.Input(shape=input_shape)
    
    x = layers.Conv2D(16, (3, 3), padding='same', kernel_initializer='he_normal')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    num_filters = 16 
    for stack in range(3):
        for block in range(18):  # 6n layers, n=18 for ResNet110
            strides = (1, 1)
            if stack > 0 and block == 0:  # first layer but not first stack
                strides = (2, 2)  # downsample
            x = ResnetBlock(num_filters, x, strides)
        num_filters *= 2
    
    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    return model


# Prepare CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Normalize pixel values to [0, 1] and subtract per-pixel mean
x_train = x_train.astype('float32')# / 255
x_test = x_test.astype('float32')# / 255
x_train -= x_train.mean(axis=0)
x_test -= x_test.mean(axis=0)

# Convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# # Add padding of 4 pixels on each side
# x_train_padded = np.pad(x_train, ((0, 0), (4, 4), (4, 4), (0, 0)), mode='reflect')

# Data augmentation
datagen = ImageDataGenerator(
    horizontal_flip=True,
    width_shift_range=8,
    height_shift_range=8
)

# Instantiate and compile the model
model = ResNet((32, 32, 3), 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
# Learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=x_train.shape[0]//256 * 20, # 200 epochs
    decay_rate=0.1, # decay to 0.1 of initial learning rate
    staircase=True)

sgd = tf.keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
# Fit the model with batch size 256
model.fit(datagen.flow(x_train, y_train, batch_size=256), 
          steps_per_epoch=len(x_train) // 256, 
          epochs=30, 
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 195/195 [==============================] - 119s 337ms/step - loss: 2.2077 - accuracy: 0.2547 - val_loss: 2.0998 - val_accuracy: 0.2590
# Epoch 2/20
# 195/195 [==============================] - 64s 329ms/step - loss: 1.6107 - accuracy: 0.4024 - val_loss: 1.4864 - val_accuracy: 0.4638
# Epoch 3/20
# 195/195 [==============================] - 64s 325ms/step - loss: 1.4475 - accuracy: 0.4697 - val_loss: 1.4843 - val_accuracy: 0.4563
# Epoch 4/20
# 195/195 [==============================] - 63s 324ms/step - loss: 1.3290 - accuracy: 0.5152 - val_loss: 1.5013 - val_accuracy: 0.4974
# Epoch 5/20
# 195/195 [==============================] - 64s 330ms/step - loss: 1.2352 - accuracy: 0.5517 - val_loss: 1.3970 - val_accuracy: 0.5190
# Epoch 6/20
# 195/195 [==============================] - 64s 329ms/step - loss: 1.1480 - accuracy: 0.5833 - val_loss: 1.1845 - val_accuracy: 0.5928
# Epoch 7/20
# 195/195 [==============================] - 63s 323ms/step - loss: 1.0816 - accuracy: 0.6127 - val_loss: 1.0666 - val_accuracy: 0.6081
# Epoch 8/20
# 195/195 [==============================] - 63s 321ms/step - loss: 1.0226 - accuracy: 0.6352 - val_loss: 1.0240 - val_accuracy: 0.6421
# Epoch 9/20
# 195/195 [==============================] - 63s 322ms/step - loss: 0.9623 - accuracy: 0.6563 - val_loss: 1.3369 - val_accuracy: 0.5793
# Epoch 10/20
# 195/195 [==============================] - 63s 324ms/step - loss: 0.9175 - accuracy: 0.6751 - val_loss: 1.0938 - val_accuracy: 0.6261
# Epoch 11/20
# 195/195 [==============================] - 64s 327ms/step - loss: 0.8774 - accuracy: 0.6868 - val_loss: 0.9148 - val_accuracy: 0.6824
# Epoch 12/20
# 195/195 [==============================] - 64s 329ms/step - loss: 0.8436 - accuracy: 0.7010 - val_loss: 1.0017 - val_accuracy: 0.6626
# Epoch 13/20
# 195/195 [==============================] - 64s 328ms/step - loss: 0.8027 - accuracy: 0.7148 - val_loss: 1.0010 - val_accuracy: 0.6586
# Epoch 14/20
# 195/195 [==============================] - 64s 325ms/step - loss: 0.7694 - accuracy: 0.7264 - val_loss: 1.0169 - val_accuracy: 0.6600
# Epoch 15/20
# 195/195 [==============================] - 64s 327ms/step - loss: 0.7420 - accuracy: 0.7351 - val_loss: 1.1060 - val_accuracy: 0.6507
# Epoch 16/20
# 195/195 [==============================] - 63s 323ms/step - loss: 0.7161 - accuracy: 0.7443 - val_loss: 1.0836 - val_accuracy: 0.6632
# Epoch 17/20
# 195/195 [==============================] - 63s 324ms/step - loss: 0.6826 - accuracy: 0.7593 - val_loss: 0.8147 - val_accuracy: 0.7274
# Epoch 18/20
# 195/195 [==============================] - 63s 324ms/step - loss: 0.6616 - accuracy: 0.7659 - val_loss: 0.7496 - val_accuracy: 0.7476
# Epoch 19/20
# 195/195 [==============================] - 64s 329ms/step - loss: 0.6361 - accuracy: 0.7761 - val_loss: 0.7170 - val_accuracy: 0.7614
# Epoch 20/20
# 195/195 [==============================] - 64s 328ms/step - loss: 0.6112 - accuracy: 0.7855 - val_loss: 0.8342 - val_accuracy: 0.7298

# %%
model.save('resnet_model.h5')

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 16)   448         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 16)  64          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 16)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 16)   2320        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 16)   0           ['activation[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  activation_2 (Activation)      (None, 32, 32, 16)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 16)   0           ['activation_2[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  activation_4 (Activation)      (None, 32, 32, 16)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 32, 32, 16)   0           ['activation_4[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 16)   0           ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 32, 32, 16)   0           ['activation_6[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_8 (Activation)      (None, 32, 32, 16)   0           ['add_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 16)  64          ['conv2d_10[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 32, 32, 16)   0           ['activation_8[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  activation_10 (Activation)     (None, 32, 32, 16)   0           ['add_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 16)  64          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 16)  64          ['conv2d_12[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 32, 32, 16)   0           ['activation_10[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  activation_12 (Activation)     (None, 32, 32, 16)   0           ['add_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 16)  64          ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 16)  64          ['conv2d_14[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 32, 32, 16)   0           ['activation_12[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  activation_14 (Activation)     (None, 32, 32, 16)   0           ['add_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 16)  64          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 16)  64          ['conv2d_16[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 32, 32, 16)   0           ['activation_14[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_16 (Activation)     (None, 32, 32, 16)   0           ['add_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 16)  64          ['conv2d_18[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 32, 32, 16)   0           ['activation_16[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  activation_18 (Activation)     (None, 32, 32, 16)   0           ['add_8[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 16)  64          ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 16)  64          ['conv2d_20[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 32, 32, 16)   0           ['activation_18[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_20 (Activation)     (None, 32, 32, 16)   0           ['add_9[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 32, 32, 16)  64          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 16)  64          ['conv2d_22[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 32, 32, 16)   0           ['activation_20[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  activation_22 (Activation)     (None, 32, 32, 16)   0           ['add_10[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 16)  64          ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 16)  64          ['conv2d_24[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 32, 32, 16)   0           ['activation_22[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_24 (Activation)     (None, 32, 32, 16)   0           ['add_11[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 16)  64          ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 16)  64          ['conv2d_26[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 32, 32, 16)   0           ['activation_24[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  activation_26 (Activation)     (None, 32, 32, 16)   0           ['add_12[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 16)  64          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 16)  64          ['conv2d_28[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 32, 32, 16)   0           ['activation_26[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  activation_28 (Activation)     (None, 32, 32, 16)   0           ['add_13[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 16)  64          ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 16)  64          ['conv2d_30[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 32, 32, 16)   0           ['activation_28[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  activation_30 (Activation)     (None, 32, 32, 16)   0           ['add_14[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 16)  64          ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 16)  64          ['conv2d_32[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 32, 32, 16)   0           ['activation_30[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  activation_32 (Activation)     (None, 32, 32, 16)   0           ['add_15[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 32, 32, 16)  64          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 32, 32, 16)  64          ['conv2d_34[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 32, 32, 16)   0           ['activation_32[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  activation_34 (Activation)     (None, 32, 32, 16)   0           ['add_16[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 32, 32, 16)  64          ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 32, 32, 16)  64          ['conv2d_36[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 32, 32, 16)   0           ['activation_34[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  activation_36 (Activation)     (None, 32, 32, 16)   0           ['add_17[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 32)   4640        ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 32)  128         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_37[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 32)   544         ['activation_36[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 16, 16, 32)  128         ['conv2d_39[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 16, 16, 32)   0           ['conv2d_37[0][0]',
#                                                                   'batch_normalization_38[0][0]']
#
#  activation_38 (Activation)     (None, 16, 16, 32)   0           ['add_18[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 16, 16, 32)  128         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 16, 16, 32)  128         ['conv2d_41[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 16, 16, 32)   0           ['activation_38[0][0]',
#                                                                   'batch_normalization_40[0][0]']
#
#  activation_40 (Activation)     (None, 16, 16, 32)   0           ['add_19[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 16, 16, 32)  128         ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 32)  128         ['conv2d_43[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 16, 16, 32)   0           ['activation_40[0][0]',
#                                                                   'batch_normalization_42[0][0]']
#
#  activation_42 (Activation)     (None, 16, 16, 32)   0           ['add_20[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 32)  128         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_43[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 16, 16, 32)  128         ['conv2d_45[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 16, 16, 32)   0           ['activation_42[0][0]',
#                                                                   'batch_normalization_44[0][0]']
#
#  activation_44 (Activation)     (None, 16, 16, 32)   0           ['add_21[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 16, 16, 32)  128         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 16, 16, 32)  128         ['conv2d_47[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 16, 16, 32)   0           ['activation_44[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  activation_46 (Activation)     (None, 16, 16, 32)   0           ['add_22[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 16, 16, 32)  128         ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 16, 16, 32)  128         ['conv2d_49[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 16, 16, 32)   0           ['activation_46[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  activation_48 (Activation)     (None, 16, 16, 32)   0           ['add_23[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 16, 16, 32)  128         ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_49[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 16, 16, 32)  128         ['conv2d_51[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 16, 16, 32)   0           ['activation_48[0][0]',
#                                                                   'batch_normalization_50[0][0]']
#
#  activation_50 (Activation)     (None, 16, 16, 32)   0           ['add_24[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 16, 16, 32)  128         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 16, 16, 32)  128         ['conv2d_53[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 16, 16, 32)   0           ['activation_50[0][0]',
#                                                                   'batch_normalization_52[0][0]']
#
#  activation_52 (Activation)     (None, 16, 16, 32)   0           ['add_25[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 16, 16, 32)  128         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 16, 16, 32)  128         ['conv2d_55[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 16, 16, 32)   0           ['activation_52[0][0]',
#                                                                   'batch_normalization_54[0][0]']
#
#  activation_54 (Activation)     (None, 16, 16, 32)   0           ['add_26[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 16, 16, 32)  128         ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_55[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 16, 16, 32)  128         ['conv2d_57[0][0]']
#  ormalization)
# ...
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 64)    256         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_91 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_91[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_91[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 64)    256         ['conv2d_94[0][0]']
#  ormalization)
#
#  add_45 (Add)                   (None, 8, 8, 64)     0           ['activation_90[0][0]',
#                                                                   'batch_normalization_92[0][0]']
#
#  activation_92 (Activation)     (None, 8, 8, 64)     0           ['add_45[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 64)    256         ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_93 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_93[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_93[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 8, 8, 64)    256         ['conv2d_96[0][0]']
#  ormalization)
#
#  add_46 (Add)                   (None, 8, 8, 64)     0           ['activation_92[0][0]',
#                                                                   'batch_normalization_94[0][0]']
#
#  activation_94 (Activation)     (None, 8, 8, 64)     0           ['add_46[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 8, 8, 64)    256         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_95 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_95[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_95[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 8, 8, 64)    256         ['conv2d_98[0][0]']
#  ormalization)
#
#  add_47 (Add)                   (None, 8, 8, 64)     0           ['activation_94[0][0]',
#                                                                   'batch_normalization_96[0][0]']
#
#  activation_96 (Activation)     (None, 8, 8, 64)     0           ['add_47[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_96[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 8, 8, 64)    256         ['conv2d_99[0][0]']
#  ormalization)
#
#  activation_97 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_97[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_97[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 8, 8, 64)    256         ['conv2d_100[0][0]']
#  ormalization)
#
#  add_48 (Add)                   (None, 8, 8, 64)     0           ['activation_96[0][0]',
#                                                                   'batch_normalization_98[0][0]']
#
#  activation_98 (Activation)     (None, 8, 8, 64)     0           ['add_48[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_98[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 8, 8, 64)    256         ['conv2d_101[0][0]']
#  ormalization)
#
#  activation_99 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_99[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_99[0][0]']
#
#  batch_normalization_100 (Batch  (None, 8, 8, 64)    256         ['conv2d_102[0][0]']
#  Normalization)
#
#  add_49 (Add)                   (None, 8, 8, 64)     0           ['activation_98[0][0]',
#                                                                   'batch_normalization_100[0][0]']
#
#  activation_100 (Activation)    (None, 8, 8, 64)     0           ['add_49[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_100[0][0]']
#
#  batch_normalization_101 (Batch  (None, 8, 8, 64)    256         ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_101 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_101[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_101[0][0]']
#
#  batch_normalization_102 (Batch  (None, 8, 8, 64)    256         ['conv2d_104[0][0]']
#  Normalization)
#
#  add_50 (Add)                   (None, 8, 8, 64)     0           ['activation_100[0][0]',
#                                                                   'batch_normalization_102[0][0]']
#
#  activation_102 (Activation)    (None, 8, 8, 64)     0           ['add_50[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_102[0][0]']
#
#  batch_normalization_103 (Batch  (None, 8, 8, 64)    256         ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_103[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_103[0][0]']
#
#  batch_normalization_104 (Batch  (None, 8, 8, 64)    256         ['conv2d_106[0][0]']
#  Normalization)
#
#  add_51 (Add)                   (None, 8, 8, 64)     0           ['activation_102[0][0]',
#                                                                   'batch_normalization_104[0][0]']
#
#  activation_104 (Activation)    (None, 8, 8, 64)     0           ['add_51[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_104[0][0]']
#
#  batch_normalization_105 (Batch  (None, 8, 8, 64)    256         ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_105[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_105[0][0]']
#
#  batch_normalization_106 (Batch  (None, 8, 8, 64)    256         ['conv2d_108[0][0]']
#  Normalization)
#
#  add_52 (Add)                   (None, 8, 8, 64)     0           ['activation_104[0][0]',
#                                                                   'batch_normalization_106[0][0]']
#
#  activation_106 (Activation)    (None, 8, 8, 64)     0           ['add_52[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_106[0][0]']
#
#  batch_normalization_107 (Batch  (None, 8, 8, 64)    256         ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_107[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_107[0][0]']
#
#  batch_normalization_108 (Batch  (None, 8, 8, 64)    256         ['conv2d_110[0][0]']
#  Normalization)
#
#  add_53 (Add)                   (None, 8, 8, 64)     0           ['activation_106[0][0]',
#                                                                   'batch_normalization_108[0][0]']
#
#  activation_108 (Activation)    (None, 8, 8, 64)     0           ['add_53[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['activation_108[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 10)           650         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 1,742,762
# Trainable params: 1,734,666
# Non-trainable params: 8,096
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Grad-CAM을 위한 함수 정의
def grad_cam(model, x, layer_name):
    # 모델의 특정 레이어의 출력과 gradient를 얻기 위한 함수 정의
    grad_model = tf.keras.models.Model([model.inputs], [model.get_layer(layer_name).output, model.output])

    # 입력 이미지에 대한 예측값과 gradient 계산
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(x)
        loss = predictions[:, tf.argmax(predictions[0])]

    # gradient 계산
    gradients = tape.gradient(loss, conv_outputs)[0]

    # 마지막 레이어의 필터별 gradient의 평균을 계산하여 중요도로 사용
    weights = tf.reduce_mean(gradients, axis=(0, 1))

    # 각 채널의 활성화 맵에 대한 가중합
    cam = tf.reduce_sum(tf.multiply(weights, conv_outputs), axis=-1)

    # 활성화 맵을 0~1로 정규화
    cam = np.maximum(cam, 0) / np.max(cam)

    return cam


# 이미지 전처리 함수
def preprocess_input(x):
    x = x.astype('float32')
    x /= 255.0
    x -= 0.5
    x *= 2.0
    return x


# CIFAR-10 데이터셋 로드
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# 이미지 전처리 및 데이터셋 준비
x_test = preprocess_input(x_test)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

# ResNet 모델 로드
model = tf.keras.models.load_model('resnet_model.h5')  # ResNet 모델 파일 경로로 수정

# Grad-CAM을 시각화할 이미지 선택
image_index = 0  # 예시로 첫 번째 이미지 사용
x = np.expand_dims(x_test[image_index], axis=0)
y_true = np.argmax(y_test[image_index])

# Grad-CAM 계산
cam = grad_cam(model, x, 'conv2d_110')

# %%
# 원본 이미지 가져오기
image = x_test[image_index]
image = (image + 1) / 2.0  # 이미지 후처리 역과정

# %%
# Grad-CAM을 원본 이미지에 적용하여 시각화
cam = cv2.resize(cam, (image.shape[1], image.shape[0]))
heatmap = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)
heatmap = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-24-53997279b5a7> in <cell line: 3>()
#       1 # Grad-CAM을 원본 이미지에 적용하여 시각화
#       2 cam = cv2.resize(cam, (image.shape[1], image.shape[0]))
# ----> 3 heatmap = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)
#       4 heatmap = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)
#
# error: OpenCV(4.7.0) /io/opencv/modules/imgproc/src/colormap.cpp:736: error: (-5:Bad argument) cv::ColorMap only supports source images of type CV_8UC1 or CV_8UC3 in function 'operator()'

# %%
# Grad-CAM을 원본 이미지에 적용하여 시각화
cam = cv2.resize(cam, (image.shape[1], image.shape[0]))
cam = cam.astype(np.uint8)  # 데이터 타입 변환
cam = cv2.cvtColor(cam, cv2.COLOR_GRAY2BGR)  # 단일 채널 이미지를 3채널 이미지로 변환

heatmap = cv2.applyColorMap(cam, cv2.COLORMAP_JET)
heatmap = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)

# 원본 이미지와 Grad-CAM 시각화
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.axis('off')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-25-55f9d84ae5b2> in <cell line: 4>()
#       2 cam = cv2.resize(cam, (image.shape[1], image.shape[0]))
#       3 cam = cam.astype(np.uint8)  # 데이터 타입 변환
# ----> 4 cam = cv2.cvtColor(cam, cv2.COLOR_GRAY2BGR)  # 단일 채널 이미지를 3채널 이미지로 변환
#       5
#       6 heatmap = cv2.applyColorMap(cam, cv2.COLORMAP_JET)
#
# error: OpenCV(4.7.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<1>; VDcn = cv::impl::{anonymous}::Set<3, 4>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = cv::impl::<unnamed>::NONE; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 8
